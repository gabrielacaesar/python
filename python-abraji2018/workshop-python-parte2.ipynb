# %% [markdown]
# # Workshop de Python - Parte 2
# ## 29 de junho de 2018
# ### Prof @turicas

# %%
import csv

# %%
leitor = csv.reader(open("brasil.csv", encoding="utf-8"))

# %%
for linha in leitor:
    print(linha)
# Out:
# ['estado', 'municipio', 'habitantes', 'area']
# ['AC', 'Acrelândia', '12538', '1807.92']
# ['AC', 'Assis Brasil', '6072', '4974.18']
# ['AC', 'Brasiléia', '21398', '3916.5']
# ['AC', 'Bujari', '8471', '3034.87']
# ['AC', 'Capixaba', '8798', '1702.58']
# ['AC', 'Cruzeiro do Sul', '78507', '8779.39']
# ['AC', 'Epitaciolândia', '15100', '1654.77']
# ['AC', 'Feijó', '32412', '27974.89']
# ['AC', 'Jordão', '6577', '5357.28']
# ['AC', 'Mâncio Lima', '15206', '5453.07']
# ['AC', 'Manoel Urbano', '7981', '10634.46']
# ['AC', 'Marechal Thaumaturgo', '14227', '8191.69']
# ['AC', 'Plácido de Castro', '17209', '1943.25']
# ['AC', 'Porto Acre', '14880', '2604.86']
# ['AC', 'Porto Walter', '9176', '6443.83']
# ['AC', 'Rio Branco', '336038', '8835.54']
# ['AC', 'Rodrigues Alves', '14389', '3076.95']
# ['AC', 'Santa Rosa do Purus', '4691', '6145.61']
# ['AC', 'Sena Madureira', '38029', '23751.47']
# ['AC', 'Senador Guiomard', '20179', '2321.45']
# ['AC', 'Tarauacá', '35590', '20171.05']
# ...

# %%
leitor = csv.reader(open("brasil.csv", encoding="utf-8"))
habitantes = 0
for linha in leitor:
    if linha[0] != "estado":
        habitantes = habitantes + int(linha[2])
print(habitantes)
# Out:
# 190755799

# %%
#

# %%
leitor = csv.reader(open("brasil.csv", encoding="utf-8"))
habitantes = 0
for linha in leitor:
    if linha[0] != "estado":
        if linha[0] == "RJ":
            habitantes = habitantes + int(linha[2])
print(habitantes)
# Out:
# 15989929

# %%
leitor = csv.reader(open("brasil.csv", encoding="utf-8"))
habitantes = 0
for linha in leitor:
    if linha[0] == "RJ" or linha[0] == "SP" or linha[0] == "MG" or linha[0] == "ES":
        habitantes = habitantes + int(linha[2])
print(habitantes)
# Out:
# 80364410

# %%
leitor = csv.reader(open("brasil.csv", encoding="utf-8"))
habitantes = 0
sudeste = ["RJ", "SP", "MG", "ES"]
for linha in leitor:
    if linha[0] in sudeste:
        habitantes = habitantes + int(linha[2])
print(habitantes)
# Out:
# 80364410

# %%
leitor = csv.reader(open("brasil.csv", encoding="utf-8"))
total = 0
sudeste = ["RJ", "SP", "MG", "ES"]
for linha in leitor:
    estado = linha[0]
    if estado in sudeste:
        habitantes = int(linha[2])
        total = total + habitantes #ou total += habitantes
print(total)
# Out:
# 80364410

# %%
leitor = csv.reader(open("brasil.csv", encoding="utf-8"))
sudeste = ["RJ", "SP", "MG", "ES"]
for linha in leitor:
    estado = linha[0]
    if estado in sudeste:
        habitantes = int(linha[2])
        area = float(linha[3])
        densidade = habitantes / area
        print(f"o município {linha[1]}, no estado {linha[0]}, tem {densidade: .2f} hab/km2")
        total = total + habitantes #ou total += habitantes)
# Out:
# o município Afonso Cláudio, no estado ES, tem  32.68 hab/km2
# o município Água Doce do Norte, no estado ES, tem  24.85 hab/km2
# o município Águia Branca, no estado ES, tem  20.95 hab/km2
# o município Alegre, no estado ES, tem  39.85 hab/km2
# o município Alfredo Chaves, no estado ES, tem  22.66 hab/km2
# o município Alto Rio Novo, no estado ES, tem  32.14 hab/km2
# o município Anchieta, no estado ES, tem  58.41 hab/km2
# o município Apiacá, no estado ES, tem  38.72 hab/km2
# o município Aracruz, no estado ES, tem  57.47 hab/km2
# o município Atilio Vivacqua, no estado ES, tem  44.08 hab/km2
# o município Baixo Guandu, no estado ES, tem  31.71 hab/km2
# o município Barra de São Francisco, no estado ES, tem  43.16 hab/km2
# o município Boa Esperança, no estado ES, tem  33.14 hab/km2
# o município Bom Jesus do Norte, no estado ES, tem  106.38 hab/km2
# o município Brejetuba, no estado ES, tem  34.62 hab/km2
# o município Cachoeiro de Itapemirim, no estado ES, tem  216.23 hab/km2
# ...

# %%
# FIM
