# %%
# módulo 3, vídeo 6

# %%
lista_senadores = {"PT": ["gleisi", "fatimabezerra", "humbertocostapt", "jorgeviana", "josepimentel", "paulopaim", "senadoraregina", "lindbergfarias", "sen_paulorocha"], "PSDB": ["aecioneves", "aloysio_nunes", "anastasia", "senador_ataides", "cassiocl", "daliriobeber", "senadordeca", "eduardoamorimse", "senadorflexa", "jose_anibal", "joseserra_", "paulobauer45", "pintoitamaraty", "ricardoferraco", "tassocomvoce"], "PMDB": ["airtonsandoval", "darioberger", "senadorlobao", "eduardobraga_am", "elmanoferrer", "eunicio", "garibaldifilho", "senador_helio", "jader_barbalho", "senjoaoalberto", "josemaranhaopb", "senadoramarta", "raimundolirapb", "renancalheiros", "requiaopmdb", "romerojuca", "senadorarose", "simonetebetms", "senadorraupp", "senadormoka", "zezeperrella"]}

# %%
import tweepy

# %%
consumer_key = 'Pv2Byvr0BTKQSY4w5gcKBwbkD'
consumer_secret = 'gDIJvdO9PJxKITsKlcIoc0jFbbiTyh5RluKl6wdOycrfXPCCZU'
access_token = '2551415983-RbRceBoZ4qxinBuF7jzYiJin6gkP5izgyOdoMhH'
access_token_secret = '463aUHkxloyH5qledrgI3kTcWWokFInNN2dJTuGFNKgPa'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
api.user_timeline("gabrielacaesar")
# Out:
# [Status(_api=<tweepy.api.API object at 0x10d962c50>, _json={'created_at': 'Fri Dec 08 23:53:30 +0000 2017', 'id': 939281815512240128, 'id_str': '939281815512240128', 'text': 'Meu top5 do Spotify em 2017: https://t.co/ru35jGsy5Z', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 939281804556750850, 'id_str': '939281804556750850', 'indices': [29, 52], 'media_url': 'http://pbs.twimg.com/media/DQj_0yCX0AIUOuk.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DQj_0yCX0AIUOuk.jpg', 'url': 'https://t.co/ru35jGsy5Z', 'display_url': 'pic.twitter.com/ru35jGsy5Z', 'expanded_url': 'https://twitter.com/gabrielacaesar/status/939281815512240128/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 750, 'h': 1334, 'resize': 'fit'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 382, 'h': 680, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 939281804556750
# ...

# %%
print(lista_senadores["PT"])
# Out:
# ['gleisi', 'fatimabezerra', 'humbertocostapt', 'jorgeviana', 'josepimentel', 'paulopaim', 'senadoraregina', 'lindbergfarias', 'sen_paulorocha']

# %%
print(lista_senadores["PSDB"])
# Out:
# ['aecioneves', 'aloysio_nunes', 'anastasia', 'senador_ataides', 'cassiocl', 'daliriobeber', 'senadordeca', 'eduardoamorimse', 'senadorflexa', 'jose_anibal', 'joseserra_', 'paulobauer45', 'pintoitamaraty', 'ricardoferraco', 'tassocomvoce']

# %%
print(lista_senadores["PMDB"])
# Out:
# ['airtonsandoval', 'darioberger', 'senadorlobao', 'eduardobraga_am', 'elmanoferrer', 'eunicio', 'garibaldifilho', 'senador_helio', 'jader_barbalho', 'senjoaoalberto', 'josemaranhaopb', 'senadoramarta', 'raimundolirapb', 'renancalheiros', 'requiaopmdb', 'romerojuca', 'senadorarose', 'simonetebetms', 'senadorraupp', 'senadormoka', 'zezeperrella']

# %%
# new exercise
import csv
import re
import urllib

# %%
def get_tweets(username):

        #http://tweepy.readthedocs.org/en/v3.1.0/getting_started.html#api
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)
        api = tweepy.API(auth)

        #set count to however many tweets you want; twitter only allows 200 at once
        number_of_tweets = 200

        #get tweets
        tweets = api.user_timeline(screen_name = "gabrielacaesar", count = number_of_tweets)

# %%
for tweet in tweets:
    urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', tweet.text)
    for url in urls:
        try:
            res = urllib2.urlopen(url)
            actual_url = res.geturl()
            print(actual_url)
        except:
            print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-143bf053a2fc> in <module>()
# ----> 1 for tweet in tweets:
#       2     urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', tweet.text)
#       3     for url in urls:
#       4         try:
#       5             res = urllib2.urlopen(url)
#
# NameError: name 'tweets' is not defined

# %%
# why isn't "tweets" defined?
