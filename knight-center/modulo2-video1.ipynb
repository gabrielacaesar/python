# %%
# módulo 2, vídeo 1

# %%
arquivo = open("output.csv", encoding="utf-8")
for linha in arquivo:
    print(linha)
# Out:
# user,text,latitude,longitude
#
#
#
# caiofelipho,"b""I'm at Sukiya | ??? in S?o Paulo, SP https://t.co/p3s5dWCnIg""",-23.55329832,-46.65502681
#
#
#
# HeyIcee,b'? @ 1007 Augusta https://t.co/FNSQW4Dp6A',-23.5510502,-46.6496582
#
#
#
# calandrx,b'Achei acidentalmente essa foto linda perdida na minha galeria @ Selva https://t.co/P204RZ5EzE',-23.55163768,-46.65089966
#
#
#
# _felipeveiga,b'Pastel - Massa de banha de porco e cacha?a recheado de camar?o ???\n.\nMelhor pastel de sua vida ?? https://t.co/0xyINRdTaM',-23.53773586,-46.65062236
#
#
#
# Paulocoach7,b'Show #ligadajusti?a ??? em Cinemark - P?tio Higien?polis https://t.co/BmjukDGiQj',-23.54188048,-46.65731783
#
#
#
# imeduardocampos,b'?@brasilboards TEAM?\n??Obrigado galera ! O rol? foi demais !??\n\n@brasilboards / @otangwheels /? https://t.co/AM9cwaim6r',-23.55154855,-46.65082012
#
#
#
# ...

# %%
arquivo = open("output.csv", encoding="utf-8")
for linha in arquivo:
    print(linha.upper())
# Out:
# USER,TEXT,LATITUDE,LONGITUDE
#
#
#
# CAIOFELIPHO,"B""I'M AT SUKIYA | ??? IN S?O PAULO, SP HTTPS://T.CO/P3S5DWCNIG""",-23.55329832,-46.65502681
#
#
#
# HEYICEE,B'? @ 1007 AUGUSTA HTTPS://T.CO/FNSQW4DP6A',-23.5510502,-46.6496582
#
#
#
# CALANDRX,B'ACHEI ACIDENTALMENTE ESSA FOTO LINDA PERDIDA NA MINHA GALERIA @ SELVA HTTPS://T.CO/P204RZ5EZE',-23.55163768,-46.65089966
#
#
#
# _FELIPEVEIGA,B'PASTEL - MASSA DE BANHA DE PORCO E CACHA?A RECHEADO DE CAMAR?O ???\N.\NMELHOR PASTEL DE SUA VIDA ?? HTTPS://T.CO/0XYINRDTAM',-23.53773586,-46.65062236
#
#
#
# PAULOCOACH7,B'SHOW #LIGADAJUSTI?A ??? EM CINEMARK - P?TIO HIGIEN?POLIS HTTPS://T.CO/BMJUKDGIQJ',-23.54188048,-46.65731783
#
#
#
# IMEDUARDOCAMPOS,B'?@BRASILBOARDS TEAM?\N??OBRIGADO GALERA ! O ROL? FOI DEMAIS !??\N\N@BRASILBOARDS / @OTANGWHEELS /? HTTPS://T.CO/AM9CWAIM6R',-23.55154855,-46.65082012
#
#
#
# ...
