# %%
import requests

# %%
url = "https://dadosabertos.camara.leg.br"

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
resposta = requests.get(url)

# %%
print(resposta.text)
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR">
# <!-- partial:partials/head-home.html -->
# <head>
#     <title>Dados Abertos da CÃ¢mara dos Deputados</title>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="shortcut icon" href="img/logos/favicon.ico">
#     <!-- <link href="dist/vendors-css/main.css" rel="stylesheet"> -->
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet">
#     <link rel="stylesheet" type="text/css" href="css/components.min.css"/>
#     <link rel="stylesheet" type="text/css" href="css/dadosabertos.min.css"/>
#     <script>
#         (function(i,s,o,g,r,a,m) i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# ...

# %%
url_n = "https://dadosabertos.camara.leg.br/api/v2/deputados"
parametros = {"formato": "json"}

# %%
resposta_n = requests.get(url_n, parametros)

# %%
print(resposta_n.json())
# Out:
# {'dados': [{'id': 178957, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178957', 'nome': 'ABEL MESQUITA JR.', 'siglaPartido': 'DEM', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36769', 'siglaUf': 'RR', 'idLegislatura': 55, 'urlFoto': 'http://www.camara.leg.br/internet/deputado/bandep/178957.jpg'}, {'id': 178864, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178864', 'nome': 'ADAIL CARNEIRO', 'siglaPartido': 'PP', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36809', 'siglaUf': 'CE', 'idLegislatura': 55, 'urlFoto': 'http://www.camara.leg.br/internet/deputado/bandep/178864.jpg'}, {'id': 178914, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178914', 'nome': 'ADALBERTO CAVALCANTI', 'siglaPartido': 'AVANTE', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36898', 'siglaUf': 'PE', 'idLegislatura': 55, 'urlFoto': 'http://www.camara.leg.br/internet/deputado/bandep/178914.jpg'}, {'id': 178890
# ...

# %%
for deputado in resposta_n.json()["dados"]:
    print(f"{deputado['nome']} ({deputado['siglaPartido']})")
# Out:
# ABEL MESQUITA JR. (DEM)
# ADAIL CARNEIRO (PP)
# ADALBERTO CAVALCANTI (AVANTE)
# ADELMO CARNEIRO LEÃO (PT)
# ADELSON BARRETO (PR)
# ADEMIR CAMILO (PODE)
# AELTON FREITAS (PR)
# AFONSO FLORENCE (PT)
# AFONSO HAMM (PP)
# AFONSO MOTTA (PDT)
# AGUINALDO RIBEIRO (PP)
# ALAN RICK (DEM)
# ALBERTO FILHO (PMDB)
# ALBERTO FRAGA (DEM)
# ALCEU MOREIRA (PMDB)

# %%
url_n = "https://dadosabertos.camara.leg.br/api/v2/deputados"
parametros2 = {"formato": "json", "itens": 100}

# %%
resposta_n = requests.get(url_n, parametros2)

# %%
for deputado in resposta_n.json()["dados"]:
    print(f"{deputado['nome']} ({deputado['siglaPartido']})")
# Out:
# ABEL MESQUITA JR. (DEM)
# ADAIL CARNEIRO (PP)
# ADALBERTO CAVALCANTI (AVANTE)
# ADELMO CARNEIRO LEÃO (PT)
# ADELSON BARRETO (PR)
# ADEMIR CAMILO (PODE)
# AELTON FREITAS (PR)
# AFONSO FLORENCE (PT)
# AFONSO HAMM (PP)
# AFONSO MOTTA (PDT)
# AGUINALDO RIBEIRO (PP)
# ALAN RICK (DEM)
# ALBERTO FILHO (PMDB)
# ALBERTO FRAGA (DEM)
# ALCEU MOREIRA (PMDB)
# ALESSANDRO MOLON (REDE)
# ALEX CANZIANI (PTB)
# ALEX MANENTE (PPS)
# ALEXANDRE LEITE (DEM)
# ALEXANDRE SERFIOTIS (PMDB)
# ALEXANDRE VALLE (PR)
# ALFREDO KAEFER (PSL)
# ALFREDO NASCIMENTO (PR)
# ALICE PORTUGAL (PCdoB)
# ALIEL MACHADO (REDE)
# ALTINEU CÔRTES (PMDB)
# ALUISIO MENDES (PODE)
# ANA PERUGINI (PT)
# ANDRÉ ABDON (PP)
# ANDRÉ AMARAL (PMDB)
# ANDRÉ DE PAULA (PSD)
# ANDRÉ FIGUEIREDO (PDT)
# ANDRÉ FUFUCA (PP)
# ANDRE MOURA (PSC)
# ANDRES SANCHEZ (PT)
# ANGELIM (PT)
# ANÍBAL GOMES (PMDB)
# ANTONIO BRITO (PSD)
# ANTONIO BULHÕES (PRB)
# ANTONIO CARLOS MENDES THAME (PV)
# ANTONIO IMBASSAHY (PSDB)
# ANTÔNIO JÁCOME (PODE)
# ...

# %%
url_n = "https://dadosabertos.camara.leg.br/api/v2/deputados"
for pagina in [1, 2, 3, 4, 5, 6]:
    parametros = {"formato": "json", "itens": 100, "pagina": pagina}
    resposta_n = requests.get(url_n, parametros2)
    for deputado in resposta_n.json()["dados"]:
        print(f"{deputado['nome']} ({deputado['siglaPartido']})")
# Out:
# ABEL MESQUITA JR. (DEM)
# ADAIL CARNEIRO (PP)
# ADALBERTO CAVALCANTI (AVANTE)
# ADELMO CARNEIRO LEÃO (PT)
# ADELSON BARRETO (PR)
# ADEMIR CAMILO (PODE)
# AELTON FREITAS (PR)
# AFONSO FLORENCE (PT)
# AFONSO HAMM (PP)
# AFONSO MOTTA (PDT)
# AGUINALDO RIBEIRO (PP)
# ALAN RICK (DEM)
# ALBERTO FILHO (PMDB)
# ALBERTO FRAGA (DEM)
# ALCEU MOREIRA (PMDB)
# ALESSANDRO MOLON (REDE)
# ALEX CANZIANI (PTB)
# ALEX MANENTE (PPS)
# ALEXANDRE LEITE (DEM)
# ALEXANDRE SERFIOTIS (PMDB)
# ALEXANDRE VALLE (PR)
# ALFREDO KAEFER (PSL)
# ALFREDO NASCIMENTO (PR)
# ALICE PORTUGAL (PCdoB)
# ALIEL MACHADO (REDE)
# ALTINEU CÔRTES (PMDB)
# ALUISIO MENDES (PODE)
# ANA PERUGINI (PT)
# ANDRÉ ABDON (PP)
# ANDRÉ AMARAL (PMDB)
# ANDRÉ DE PAULA (PSD)
# ANDRÉ FIGUEIREDO (PDT)
# ANDRÉ FUFUCA (PP)
# ANDRE MOURA (PSC)
# ANDRES SANCHEZ (PT)
# ANGELIM (PT)
# ANÍBAL GOMES (PMDB)
# ANTONIO BRITO (PSD)
# ANTONIO BULHÕES (PRB)
# ANTONIO CARLOS MENDES THAME (PV)
# ANTONIO IMBASSAHY (PSDB)
# ANTÔNIO JÁCOME (PODE)
# ...

# %%
url_n = "https://dadosabertos.camara.leg.br/api/v2/deputados"

deputados = []

for pagina in [1, 2, 3, 4, 5, 6]:
    print(pagina)
    parametros = {"formato": "json", "itens": 100, "pagina": pagina}
    resposta_n = requests.get(url_n, parametros2)
    for deputado in resposta_n.json()["dados"]:
        deputados.append(deputado["nome"])
print(len(deputados))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 600

# %%
# fim
